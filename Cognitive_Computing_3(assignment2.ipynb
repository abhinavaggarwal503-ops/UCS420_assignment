# %% [markdown]
# #Q1

# %%
rollno = 1024160080

L=[]

for i in range(10):
  L.append((rollno % 10)*10)
  rollno = rollno//10

L.reverse()
print(L)
# Out:
# [10, 0, 20, 40, 10, 60, 0, 0, 80, 0]

# %%
L.append(28)
print(L)

L.insert(2,92)
print(L)

L.pop()
print(L)

L.remove(92)
print(L)
# Out:
# [10, 0, 20, 40, 10, 60, 0, 0, 80, 0, 28]
# [10, 0, 92, 20, 40, 10, 60, 0, 0, 80, 0, 28]
# [10, 0, 92, 20, 40, 10, 60, 0, 0, 80, 0]
# [10, 0, 20, 40, 10, 60, 0, 0, 80, 0]

# %%
L.sort()
print(L)
L.sort(reverse=True)
print(L)
# Out:
# [0, 0, 0, 0, 10, 10, 20, 40, 60, 80]
# [80, 60, 40, 20, 10, 10, 0, 0, 0, 0]

# %%
print(L[:3]+L[-3:])
# Out:
# [80, 60, 40, 0, 0, 0]

# %%
m = sum(L)/len(L)
print(m)
L1 = []

for i in range(len(L)):
  if L[i]>m:
    L1.append(L[i])

print(L1)
# Out:
# 22.0
# [80, 60, 40]

# %% [markdown]
# #Q2

# %%
R = tuple(L[:8])

print(R)

maxx=0
index=0
for i in range(len(R)):
  if R[i] > maxx:
    max=R[i]
    index=i

print(maxx)
print(index)

count=0

for i in range(len(R)):
  if R[i] == min(R):
    count+=1

print(min(R))
print(count)
# Out:
# (80, 60, 40, 20, 10, 10, 0, 0)
# 0
# 5
# 0
# 2

# %%
R1 = list(R)
R1.reverse()
print(R1)
# Out:
# [0, 0, 10, 10, 20, 40, 60, 80]

# %%
a = int(input("Please Enter a no. "))
for i in range(len(R)):
  if R[i] == a:
    print(i)
    break
else:
  print("not present message")
# Out:
# Please Enter a no. 40
# 2

# %%
R[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_382/1903329345.py in <cell line: 0>()
# ----> 1 R[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
first,second, *remaining = R
print(first,second,remaining)
# Out:
# 80 60 [40, 20, 10, 10, 0, 0]

# %% [markdown]
# #Q3

# %%
import random

random.seed(1024160080)
numbers = [random.randint(100,900) for _ in range(100)]
print(numbers)
# Out:
# [756, 492, 878, 785, 587, 849, 482, 469, 328, 288, 754, 839, 316, 852, 469, 450, 292, 491, 897, 286, 279, 207, 329, 535, 831, 180, 861, 445, 156, 607, 808, 161, 436, 532, 506, 276, 562, 771, 329, 893, 257, 554, 892, 328, 246, 801, 709, 287, 564, 176, 381, 642, 551, 299, 288, 138, 781, 329, 666, 364, 756, 141, 110, 631, 555, 192, 899, 774, 454, 202, 310, 857, 411, 713, 900, 521, 614, 455, 189, 671, 189, 565, 136, 681, 333, 361, 159, 700, 833, 802, 743, 836, 313, 807, 881, 458, 447, 562, 219, 383]

# %%
count = 0
for i in range(len(numbers)):
  if numbers[i]%2 != 0:
    count+=1

print(count)
# Out:
# 54

# %%
count = 0
for i in range(len(numbers)):
  if numbers[i]%2 == 0:
    count+=1

print(count)
# Out:
# 46

# %%
k=[]

for i in range(len(numbers)):
  for j in range(2,int((numbers[i]/2)+1)):
    if numbers[i]%j == 0:
      break
  else:
    k.append(numbers[i])

print(k)
# Out:
# [587, 839, 491, 607, 257, 709, 631, 857, 521, 743, 313, 881, 383]

# %%
del max

# %%
dic = {}


for i in range(len(numbers)):
    if numbers[i] in dic:
        dic[numbers[i]] += 1
    else:
        dic[numbers[i]] = 1

print(max(dic, key=dic.get))
# Out:
# 329

# %% [markdown]
# #Q4

# %%
rollno = 1024160080
print(rollno)

A=set()
B=set()

for i in range(8):
  A.add((rollno % 10)*7)
  B.add((rollno % 10)*9)
  rollno = rollno//10


print(A)
print(B)
# Out:
# 1024160080
# {0, 7, 42, 14, 56, 28}
# {0, 36, 72, 9, 18, 54}

# %%
print(A.union(B))

print(A.intersection(B))

print(A.difference(B))

print(B.difference(A))

print(A.symmetric_difference(B))
# Out:
# {0, 36, 7, 72, 9, 42, 14, 18, 54, 56, 28}
# {0}
# {7, 42, 14, 56, 28}
# {36, 72, 9, 18, 54}
# {7, 72, 9, 14, 18, 28, 36, 42, 54, 56}

# %%
print(A.issubset(B))

print(B.issuperset(A))
# Out:
# False
# False

# %%
X = int(input("Enter a value: "))

print(A)
A.discard(X) #If the item to remove does not exist, discard() will NOT raise an error
print(A)
# Out:
# Enter a value: 56
# {0, 7, 42, 14, 56, 28}
# {0, 7, 42, 14, 28}

# %% [markdown]
# #Q5

# %%
my_dict = { "name": "Abhinav",
           "roll_no": "1024160080",
            "branch": "CSE",
            "age": 21,
            "city": "Punjab" }

# %%
my_dict.pop("city")

my_dict["location"] = "PB"

my_dict
# Out:
# {'name': 'Abhinav',
#  'roll_no': '1024160080',
#  'branch': 'CSE',
#  'age': 21,
#  'location': 'PB'}

# %%
my_dict["CGPA"] = 7.82

my_dict
# Out:
# {'name': 'Abhinav',
#  'roll_no': '1024160080',
#  'branch': 'CSE',
#  'age': 21,
#  'location': 'PB',
#  'CGPA': 7.82}

# %%
my_dict["age"] += 1

my_dict
# Out:
# {'name': 'Abhinav',
#  'roll_no': '1024160080',
#  'branch': 'CSE',
#  'age': 22,
#  'location': 'PB',
#  'CGPA': 7.82}

# %%
my_dict1 = dict()
my_dict1 = my_dict.copy()
my_dict1
# Out:
# {'name': 'Abhinav',
#  'roll_no': '1024160080',
#  'branch': 'CSE',
#  'age': 22,
#  'location': 'PB',
#  'CGPA': 7.82}

# %%
print(my_dict.pop("branch"))

del my_dict1["branch"]

# pop() removes and returns the deleted item, while del removes it without returning anything.

print(my_dict)
print(my_dict1)
# Out:
# CSE
# {'name': 'Abhinav', 'roll_no': '1024160080', 'age': 22, 'location': 'PB', 'CGPA': 7.82}
# {'name': 'Abhinav', 'roll_no': '1024160080', 'age': 22, 'location': 'PB', 'CGPA': 7.82}

# %%
for x,y in my_dict.items():
  print(str(x)+"->"+str(y))
# Out:
# name->Abhinav
# roll_no->1024160080
# age->22
# location->PB
# CGPA->7.82

# %%
if "email" in my_dict:
    print(my_dict["email"])
else:
    print("Email key does not exist.")
# Out:
# Email key does not exist.

# %%
friend_dict = {
    "name": "Raghu",
    "age": 20,
    "branch": "ECE",
    "city": "Mumbai",
    "college": "ABC College"
}

merged_dict = {**my_dict, **friend_dict}

print(merged_dict) # If both dictionaries have the same key, the value from the second dictionary (friend_dict) wins/overwrites the value from my_dict.
# Out:
# {'name': 'Raghu', 'roll_no': '1024160080', 'age': 20, 'location': 'PB', 'CGPA': 7.82, 'branch': 'ECE', 'city': 'Mumbai', 'college': 'ABC College'}

# %%
string_dict = {key: value for key, value in my_dict.items() if isinstance(value, str)}

print(string_dict)
# Out:
# {'name': 'Abhinav', 'roll_no': '1024160080', 'location': 'PB'}
