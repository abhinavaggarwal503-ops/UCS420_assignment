# %%
x=10
if x==10:
  print("true")
else: print("false")
# Out:
# true

# %%
x=200
if (x%2==0): print("even")
else: print("odd")
# Out:
# even

# %%
x=int(input("enter a number"))
is_prime=True
if x<1:
  is_prime=False
else:
  for i in range(2,x):
    if x%i==0:
      is_prime=False

if is_prime:
  print("prime")
else:
  print("not a prime")
# Out:
# enter a number23
# prime

# %% [markdown]
# assignment 5.1 :- wap to find max among three numbers and input from user

# %%
x=int(input("first number:"))
y=int(input("second number:"))
z=int(input("third number:"))
a=max(x,y)
b=max(a,z)
print(b)
# Out:
# first number:65
# second number:45
# third number:48
# 65

# %% [markdown]
# assignmret5.2:- wap to add all numbers divisible by 7 and 9 from 1 to n and n is given by the user

# %%
x=int(input("enter a number"))
sum=0
for i in range(1,x+1):
  if i%7==0 and i%9==0:
    sum=sum+i
print(sum)
# Out:
# enter a number100
# 63

# %% [markdown]
# assignment5.3:- wap to add all the prime numbers from 1 to n and n is given by the user

# %%
def check_prime(n):
  if n<1:
    return False
  else:
    for i in range(2,n):
      if n%i==0:
        return False
      else:
        continue
    return True



x=int(input("enter a number"))
s=0
for i in range(2,x):
  if check_prime(i):

    s=s+i
print(s)
# Out:
# enter a number26
# 100

# %%
def Add(a,b):
  c=a+b
  return c
print("add(10,30)",Add(10,30))
# Out:
# add(10,30) 40

# %%
def check_prime(n):
  if n<1:
    return False
  else:
    for i in range(2,n):
      if n%i==0:
        return False
      else:
        continue
    return True
x=int(input("enter the number"))
if check_prime(x):
  print("prime")
else:
  print("not prime")
# Out:
# enter the number26
# not prime

# %% [markdown]
# assingment 6.1:- wap using function that add all odd numbers from 1 to n and n is given by the user

# %%
def addodd(n):
  sum=0
  for i in range(1,n+1):
    if i%2!=0:
      sum=sum+i
  return sum
x=int(input("enter a number"))
print(addodd(x))
# Out:
# enter a number20
# 100

# %% [markdown]
# assingment 6.2:- wap using function that add all prime number from 1 to n, n is given by the user

# %%
def check_prime(n):
  if n<1:
    return False
  else:
    for i in range(2,n):
      if n%i==0:
        return False
      else:
        continue
    return True



x=int(input("enter a number"))
s=0
for i in range(2,x):
  if check_prime(i):

    s=s+i
print(s)
# Out:
# enter a number43
# 238

# %%
import math as m
print("exp(-290)",m.exp(-290))
print("log(10,2)",m.log(10,2))
print("log(1000,10)",m.log(1000,10))
print("log10(100)",m.log10(100))
print("cos(60)",m.cos(60))
print("sin(60)",m.sin(60))
print("tan(60)",m.tan(60))
print("sqrt(300)",m.sqrt(300))
print("ceil(89.9)",m.ceil(89.9))
print("floor(89.9)",m.floor(89.9))
# Out:
# exp(-290) 1.1339665610377455e-126
# log(10,2) 3.3219280948873626
# log(1000,10) 2.9999999999999996
# log10(100) 2.0
# cos(60) -0.9524129804151563
# sin(60) -0.3048106211022167
# tan(60) 0.320040389379563
# sqrt(300) 17.320508075688775
# ceil(89.9) 90
# floor(89.9) 89

# %%
x="abhinav"
print("x",x)
print("x[0]",x[0])
print("x[1:3]",x[1:3])
print("x[:-5]",x[:-5])
# Out:
# x abhinav
# x[0] a
# x[1:3] bh
# x[:-5] ab

# %%
x="abhinav aggarwal"
print("string",x)
print("length",len(x))
print("upper",x.upper())
print("lower",x.lower())
# Out:
# string abhinav aggarwal
# length 16
# upper ABHINAV AGGARWAL
# lower abhinav aggarwal

# %%
name=input("enter your name: ")
age=int(input("enter your age: "))
price=float(input("enter the book price: "))
s="\nyour name is %s, age is %d and book price is %f" %(name.upper(),age,price)
print(s)
# Out:
# enter your name: abhinav
# enter your age: 21
# enter the book price: 999
#
# your name is ABHINAV, age is 21 and book price is 999.000000

# %%
x="""Python strings are sequences of characters that can be accessed using indexing and slicing.
Indexing is used to access a single character from a string.
Slicing is used to extract a specific part of a string using a start and end index."""
x
# Out:
# 'Python strings are sequences of characters that can be accessed using indexing and slicing.\nIndexing is used to access a single character from a string.\nSlicing is used to extract a specific part of a string using a start and end index.'

# %%
x="  Indian   Army     "
print(x)
print(len(x))
print(x.strip())
print(len(x.strip()))
# Out:
#   Indian   Army
# 20
# Indian   Army
# 13

# %%
x="  Indian   Army     "
print(x)
print(len(x))
print(x.split())
print(x.split(' '))
print(x.split(','))

# strip+split
x.strip().split()
# Out:
#   Indian   Army
# 20
# ['Indian', 'Army']
# ['', '', 'Indian', '', '', 'Army', '', '', '', '', '']
# ['  Indian   Army     ']
# ['Indian', 'Army']

# %%
x="  Indian   Army     "
print(x)
print(x.count(' '))
print(x.count('a'))
print(x.count('an'))
# Out:
#   Indian   Army
# 10
# 1
# 1

# %%
x="Indian Army"
print(x)
print(x[::1])
print(x[::2])
print(x[::-1])
print(x[::-2])
# Out:
# Indian Army
# Indian Army
# Ida ry
# ymrA naidnI
# yr adI

# %%
x="Abhinav"
y="Indian Army"
z="madam"
a="level"
print(x==x[::-1])
print(y==y[::-1])
print(z==z[::-1])
print(a==a[::-1])
# Out:
# False
# False
# True
# True
