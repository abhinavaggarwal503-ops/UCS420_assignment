# %%
import numpy as np

# %% [markdown]
# Ques1

# %%
arr=np.array([1,2,3,4,5,6])
arr
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
arr+2
# Out:
# array([3, 4, 5, 6, 7, 8])

# %%
arr*3
# Out:
# array([ 3,  6,  9, 12, 15, 18])

# %%
arr/2
# Out:
# array([0.5, 1. , 1.5, 2. , 2.5, 3. ])

# %% [markdown]
# ques2

# %%
arr=np.array([1,2,3,4,5])
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
rev_arr=arr[::-1]
rev_arr
# Out:
# array([5, 4, 3, 2, 1])

# %%
x=np.array([1,2,3,4,5,1,2,1,1,1])
y=np.array([1,1,1,2,3,4,2,4,3,3])

# %%
values,counts = np.unique(y, return_counts=True)
most_frequent = values[np.argmax(counts)]

indices = np.where(x == most_frequent)[0]

print("Most frequent value:", most_frequent)
print("Frequency:", np.max(counts))
print("Indices:", indices)
# Out:
# Most frequent value: 1
# Frequency: 3
# Indices: [0 5 7 8 9]

# %%
values,counts = np.unique(y, return_counts=True)

most_frequent = values[np.argmax(counts)]

indices = np.where(y == most_frequent)[0]

print("Most frequent value:", most_frequent)
print("Frequency:", np.max(counts))
print("Indices:", indices)
# Out:
# Most frequent value: 1
# Frequency: 3
# Indices: [0 1 2]

# %% [markdown]
# ques3

# %%
arr=np.array([[10,20,30],[40,50,60],[70,80,90]])
arr
# Out:
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])

# %%
arr[0,1]
# Out:
# np.int64(20)

# %%
arr[2,0]
# Out:
# np.int64(70)

# %% [markdown]
# ques4

# %%
abhinav=np.linspace(10,100,25)
abhinav
# Out:
# array([ 10.  ,  13.75,  17.5 ,  21.25,  25.  ,  28.75,  32.5 ,  36.25,
#         40.  ,  43.75,  47.5 ,  51.25,  55.  ,  58.75,  62.5 ,  66.25,
#         70.  ,  73.75,  77.5 ,  81.25,  85.  ,  88.75,  92.5 ,  96.25,
#        100.  ])

# %%
abhinav.ndim
# Out:
# 1

# %%
abhinav.shape
# Out:
# (25,)

# %%
abhinav.size
# Out:
# 25

# %%
abhinav.dtype
# Out:
# dtype('float64')

# %%
abhinav.nbytes
# Out:
# 200

# %%
transpose=abhinav.reshape(1,25)
transpose
# Out:
# array([[ 10.  ,  13.75,  17.5 ,  21.25,  25.  ,  28.75,  32.5 ,  36.25,
#          40.  ,  43.75,  47.5 ,  51.25,  55.  ,  58.75,  62.5 ,  66.25,
#          70.  ,  73.75,  77.5 ,  81.25,  85.  ,  88.75,  92.5 ,  96.25,
#         100.  ]])

# %%
transpose.T
# Out:
# array([[ 10.  ],
#        [ 13.75],
#        [ 17.5 ],
#        [ 21.25],
#        [ 25.  ],
#        [ 28.75],
#        [ 32.5 ],
#        [ 36.25],
#        [ 40.  ],
#        [ 43.75],
#        [ 47.5 ],
#        [ 51.25],
#        [ 55.  ],
#        [ 58.75],
#        [ 62.5 ],
#        [ 66.25],
#        [ 70.  ],
#        [ 73.75],
#        [ 77.5 ],
#        [ 81.25],
#        [ 85.  ],
#        [ 88.75],
#        [ 92.5 ],
#        [ 96.25],
#        [100.  ]])

# %% [markdown]
# ques5

# %%
ucs420_abhinav=np.array([[10,20,30,40],[50,60,70,80],[90,15,20,35]])
ucs420_abhinav
# Out:
# array([[10, 20, 30, 40],
#        [50, 60, 70, 80],
#        [90, 15, 20, 35]])

# %%
np.mean(ucs420_abhinav)
# Out:
# np.float64(43.333333333333336)

# %%
np.median(ucs420_abhinav)
# Out:
# np.float64(37.5)

# %%
np.max(ucs420_abhinav)
# Out:
# np.int64(90)

# %%
np.min(ucs420_abhinav)
# Out:
# np.int64(10)

# %%
np.unique(ucs420_abhinav)
# Out:
# array([10, 15, 20, 30, 35, 40, 50, 60, 70, 80, 90])

# %%
reshaped_ucs420_abhinav = ucs420_abhinav.reshape(4, 3)
reshaped_ucs420_abhinav
# Out:
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90],
#        [15, 20, 35]])

# %%
resized_ucs420_abhinav = np.resize(ucs420_abhinav, (2, 3))
resized_ucs420_abhinav
# Out:
# array([[10, 20, 30],
#        [40, 50, 60]])
